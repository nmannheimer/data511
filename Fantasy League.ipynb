# %%
import pandas as pd
import numpy as np
import json
import requests

# %%
def get_data(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()
        players = pd.DataFrame(data['elements'])
        return players
    except requests.exceptions.RequestException as e:
            print(f"There was an error: {e} while retrieving data")
        
df = get_data("https://fantasy.premierleague.com/api/bootstrap-static/")
df

    
# top_level = ['events', 'game_settings', 'phases', 'teams', 'elements', 'element_stats', 'element_types']
# Out:
#      chance_of_playing_next_round  chance_of_playing_this_round    code  \
# 0                             0.0                           0.0  438098
# 1                           100.0                         100.0  205651
# 2                           100.0                         100.0  226597
# 3                           100.0                          75.0  219847
# 4                             0.0                           0.0  463748
# ..                            ...                           ...     ...
# 673                         100.0                         100.0  510362
# 674                          50.0                          50.0  560248
# 675                           NaN                           NaN  509291
# 676                           NaN                           NaN  463212
# 677                           NaN                           NaN  517179
#
#      cost_change_event  cost_change_event_fall  cost_change_start  \
# ...

# %%
df = pd.read_csv("players.csv")
df.head()
df.columns
# Out:
# Index(['id', 'name', 'now_cost', 'position', 'team',
#        'chance_of_playing_next_round', 'expected_goals_per_90', 'creativity',
#        'event_points', 'news', 'direct_freekicks_order',
#        'expected_goals_conceded', 'chance_of_playing_this_round',
#        'transfers_in', 'status', 'region', 'transfers_out', 'form_rank',
#        'form_rank_type', 'goals_conceded', 'dreamteam_count',
#        'transfers_out_event', 'threat_rank', 'points_per_game_rank',
#        'goals_scored', 'points_per_game_rank_type', 'cost_change_start_fall',
#        'goals_conceded_per_90', 'cost_change_event', 'cost_change_start',
#        'cost_change_event_fall', 'own_goals', 'expected_goal_involvements',
#        'now_cost_rank', 'threat', 'creativity_rank', 'news_added', 'bonus',
#        'selected_rank_type', 'expected_assists', 'selected_rank', 'form',
#        'clean_sheets_per_90', 'influence_rank', 'minutes', 'assists',
# ...

# %%
df["position"].unique()
# Out:
# array(['MID', 'FWD', 'DEF', 'GKP'], dtype=object)
